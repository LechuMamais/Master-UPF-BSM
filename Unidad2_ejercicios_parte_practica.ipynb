# %% [markdown]
# Introducción a Python
# ============================
#
# Ejercicios Parte práctica
# -----------------------------------------------------

# %% [markdown]
# ### Ejercicio 1
#
# a) Queremos crear un programa que, dados dos números, nos diga si el primero es mayor que el segundo. Por ejemplo, 2 es mayor a 1? True.
#
# b) Modifica el código para que el usuario introduzca los 2 números por pantalla.

# %%
# Respuesta:
a = input("Ingresa el primer número: ")
b = input("Ingresa el segundo número: ")
if(int(a)>int(b)):print("El primer número es mayor")
elif(int(a)==int(b)):print("Los números son iguales")
else:print("El segundo número es mayor")

# %% [markdown]
# ### Ejercicio 2
#
# a) Crea una lista con los doce meses del año, de Enero a Diciembre.
#
# b) Selecciona de la lista los meses impares y muéstralos por pantalla.
#
# c) Muestra la lista de meses invertida (ordenada de Diciembre a Enero).
#
# d) Crea las listas `primavera`,`verano`, `otoño`,` invierno`, que incluyan los meses correspondientes (e.g. primavera incluye los meses marzo, abril y mayo), a partir de los elementos de la lista de meses.
#
# e) Crea un código que, dado un elemento `mes` (e.g. Enero) de la lista, muestre la frase siguiente:
#
# "El mes del año que más me gusta es Enero".
#
# f) Modifica el código del apartado e) para que el usuario introduzca el mes por pantalla.

# %%
# Respuestas:
# a)
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"]

# b)
print(meses[0::2])
# c)
print(meses[::-1])

# d)
primavera = meses[3:6]
verano = meses[6:9]
otoño = meses[9:12]
invierno = meses[0:3]

print(primavera)
print(verano)
print(otoño)
print(invierno)

# e)
mes = 'Enero'
print('El mes del año que más me gusta es: '+mes)

# f)
def mes_fav_input():
    return input('Ingresa tu mes favorito: ')

def best_month_check():
    mes_fav = mes_fav_input()
    if mes_fav in meses:
        print('El mes del año que más me gusta es: '+mes_fav)
    else:
        print('El mes no está en la lista, introduce un valor correcto: ' + ", ".join(meses))
        best_month_check()

best_month_check()

# %% [markdown]
# ### Ejercicio 3
#
#
# Escribe un programa que, dado un string `dia` que haga referencia a un día de la semana, imprima si el contenido de este string es un día del fin de semana. Por ejemplo, si `dia` es `lunes`, debería mostrar por pantalla una cadena de caracteres con el siguiente formato:
#
# ```El lunes es fin de semana? : False.```
#
# **Nota 1** : Para resolver este ejercicio podéis buscar información en *Stackoverflow*: https://stackoverflow.com/questions/10406130/check-if-something-is-not-in-a-list-in-python/10406143
#
# **Nota 2**: Podemos suponer que el dia introducido siempre está en minúscula.

# %%
# Respuesta
def is_week(day): return day.lower() in ('lunes', 'martes', 'miércoles', 'jueves', 'viernes')
def is_weekend(day): return day.lower() in ('sábado', 'domingo')

def weekend_check(day):
  if is_week(day): print('El ' + day + ' es fin de semana? : False')
  elif is_weekend(day): print('El ' + day + ' es fin de semana? : True')
  else: print('El ' + day + ' no es un día de semana')

# %% [markdown]
# ### Ejercicio 4
#
# Nos gusta mucho la UFC, por eso hemos decidido guardar la información del top5 (campeón + top 1-4)  de luchadores de peso ligero (*light weight*), con su respectiva posición.
#
# a) Escoge el tipo de variable de python más adecuada para esta tarea y llena la variable con la información.
#
# b) Por motivos antidopping, se nos pide eliminar el luchador #4. Haz esta modificación.
#
# c) Como hemos quitado un luchador, añade el luchador número 5 al ranking para tener el nuevo top5.

# %% [markdown]
# **Nota**: Podéis usar la siguiente tabla de posiciones:
#
# |Posición	|Nombre	 |
# | :- | :-: |
# |C	|Ilia Topuria|
# |1	|Islam Makhachev|
# |2	|Arman Tsarukyan|
# |3	|Max Holloway|
# |4	|Charles Oliveira|
# |5	|Justin Gaethje|

# %%
# Respuesta
# Utilizaremos una tupla de listas para poder modificar los elementos
TOP = (['C', 'Ilia Topuria'], ['1', 'Islam Makhachev'], ['2', 'Arman Tsarukyan'], ['3', 'Max Holloway'], ['4', 'Charles Oliveira'])

def change_player(index, player_added):
    TOP[index][1] = player_added
    print(TOP)

change_player(4, 'Justin Gaethje')

# %% [markdown]
# ### Ejercicio 5
#
# A partir de la lista numeros = [1, 2, 3, 4, 5]:
#
# a) Duplica el valor del último elemento de la lista y muestra la lista modificada por pantalla.
#
# b) Crea una tupla a partir de la lista anterior.
#
# c) Duplica el valor del primer elemento de la tupla y muestra la tupla modificada por pantalla.
#
#
# ¿Qué ocurre con la tupla? ¿Por qué? Razona la respuesta.

# %%
# Respuestas

num = [1, 2, 3, 4, 5]

# a)
num[len(num)-1] = len(num)*2
print(num)

#b)
tupla = tuple(num)

# c)
tupla[0] = tupla[0]*2
print(tupla)

"""
El valor del primer elemento de la tupla no se modifica,
debido a la inmutabilidad de las tuplas.
"""
# Out:
# Running cells with '.venv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Lechu/Master UPF BSM/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## Ejercicio 6
#
# El código que se presenta a continuación no funciona. Corrige los errores y explica por qué suceden.

# %%
classe = "Introducción a Python"

n_sesiones = 6

h_sesion = "3"

horas_total = n_sesiones*h_sesion

print(f"{classe} tiene {n_sesiones} sesiones de {h_sesion} horas, que son un total de {horas_total} horas.")
# Out:
# Introducción a Python tiene 6 sesiones de 3 horas, que son un total de 333333 horas.

# %%
# Respuesta
"""
El código anterior contiene un error de tipo, ya que se está intentando multiplicar
una cadena de texto (h_sesion) por un número entero (n_sesiones).
"""

# Código corregido:

classe = "Introducción a Python"
n_sesiones = 6
h_sesion = "3"
horas_total = n_sesiones*int(h_sesion)

print(f"{classe} tiene {n_sesiones} sesiones de {h_sesion} horas, que son un total de {horas_total} horas.")
