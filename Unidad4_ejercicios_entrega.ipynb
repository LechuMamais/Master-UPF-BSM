# %% [markdown]
# Introducción a Python
# ============================
#
# Unidad 4 - Librería NumPy
# -----------------------------------------------------

# %% [markdown]
# ### Ejercicio 1
#
# En este ejercicio vamos a trabajar operaciones y propiedades de matrices.
#
# (**3 puntos**)
#
# a1) Crea una matriz $M$ de dimensiones 6x6 formada por números aleatorios comprendidos entre 1 y 10. (**0.25 puntos**)

# %% [markdown]
# a2) Crea una matriz identidad 6x6. (**0.25 puntos**)

# %% [markdown]
# b) Comprueba que la matriz identidad es correcta, es decir, que solo tiene valor de 1 en la diagonal, y el resto de la matriz es zero. (**0.5 puntos**)
#
# **Nota**: Para este ejercicio, usa funciones ya creadas de NumPy que puedes encontrar en la [documentación](https://numpy.org/doc/stable/reference/routines.array-creation.html) como diag, triu/tril o triu_indices_from/tril_indices_from (hay diferentes opciones que se pueden usar, depende de como se plantee el problema).

# %% [markdown]
# c) A continuación, en vez de usar las funciones de NumPy, crea unas funciones con tu conocimiento de estructuras de control (condicionales y fors) y slicing de matrices:
#
# - Función para obtener los elementos de la diagonal.
#
# - Función para obtener los elementos del triángulo superior de la matriz (sin diagonal) **Opcional**
# - Función para obtener los elementos del triángulo inferior de la matriz (sin diagonal) **Opcional**
#
# Comprueba que tus funciones dan lo mismo que las funciones de NumPy. Puedes usar la matriz M del apartado a) para verificarlo.
#
# (**0.5 puntos**)

# %% [markdown]
# d) Ahora que hemos comprobado que las matrices son correctas, haz las siguientes operaciones:
#
# - M + I
# - M - I
# - M * I (multiplicación elemento por elemento)
# - M * I (multiplicación matricial)
# - Determinante de M
# - Determinante de I
#
# (**1 punto**)

# %% [markdown]
# e) Para acabar, contesta las preguntas siguientes:
#
# - ¿Por qué la multiplicación matricial de M*I vuelve a dar M?
# - ¿Las matrices M e I son invertibles?
#
# (**0.5 puntos**)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 2
#
# Crea un array unidimensional (1D) de NumPy compuesto por 16 elementos que corresponden a reales (float) en el rango de 5 a 20, ordenados de manera descendente.  (**0.5 puntos**)
#
# A continuación, haz las modificaciones siguientes:
#
# - Cambia el signo de aquellos elementos que caigan en el intervalo de 10 a 15 (incluídos). (**0.5 puntos**)
#
# - Divide entre 3 los elementos en posición impar (e.g. en la lista `[1, 2, 3, 4, 5]`, los elementos 1, 3 y 5 estarían en la posición impar). Los elementos resultantes tienen que tener solo 2 decimales. (**0.5 puntos**)
#
# Muestra los resultados por pantalla.
#
# (**1.5 puntos**)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 3
#
# En este ejercicio vamos a usar nuestros conocimientos de estructuras de control (bucles fors e if), para rellenar una matriz en función de unas condiciones.
#
# a) Crea una matriz de 4x4 vacía. (**0.5 puntos**)
#
# b) Rellena la matriz siguiendo las siguientes indicaciones: (**1 punto**)
#
# Considerando los valores de cada posición  `(i, j)`:
# - Para todo `i` múltiplo de 2 (es decir, que la división entre 2 tenga módulo 0), el valor tiene que corresponder a `(i - 1)*j`.
# - Para el resto de posiciones, el valor será `(2j + 1)/i`.
#
# (**1.5 puntos**)
#
# **Nota**: Los números múltiples de 2 son aquellos que, al hacer la división del número entre 2 tienen módulo = 0.

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 4
#
# a) En el último ejercicio de la sessión práctica vimos como crear una matriz de zeros con el borde de unos. En este caso, queremos crear una matriz `B` con las siguientes características:
#
# - Tamaño 10x10
# - Diagonal con valor 1 y su inversa con valor de -1, siguiendo la forma de una `X`.
# - Los otros elementos de la matriz (que no son ni la diagonal ni la diagonal inversa) con valor 5.
#
# (**1 punto**)
#
# **Importante**: Para responder este apartado, se deben usar **funciones de NumPy**. No es necesario usar estructuras de control (bucles for o if). Algunas funciones que os podrían ser de utilidad son [fill_diagonal](https://numpy.org/doc/stable/reference/generated/numpy.fill_diagonal.html) y [fliplr](https://numpy.org/doc/stable/reference/generated/numpy.fliplr.html).
#
# b) Comprueba (mediante código, no solo visualizándolo) que la matriz se ha creado correctamente, es decir:
# - En la diagonal solo hay elementos de valor 1.
# - En la diagonal inversa solo hay elementos de valor -1.
# - Todos los otros elementos tienen valor 5.
#
# (**0.5 puntos**)
#
# **Opcional:** Después de hacer el apartado b), podéis comprobar el resultado con la función [imshow](https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.imshow.html) de Matplotlib que nos permite visualizar una imagen 2D.
#
# (**1.5 puntos**)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 5
#
# Como docentes universitarios, hemos optado por incorporar Python en nuestras labores académicas con el fin de optimizar nuestras tareas. Para asegurarnos de estar debidamente preparados antes del inicio del curso, estamos desarrollando diversos fragmentos de código que serán de utilidad en futuros análisis con datos reales.
#
# En esta primera etapa, vamos a generar datos sintéticos que simulen las calificaciones correspondientes a 6 entregas de evaluación para un grupo de 32 estudiantes.
#
# a) Crea una matriz 32x6 con valores aleatorios del 1 al 10.  (**0.25 puntos**)
#
# Ahora que disponemos de las calificaciones simuladas, procedamos a explorar qué información podemos extraer de ellas.
#
# b) Calcula la media de las 6 entregas por cada alumno. Si el aprobado es un 5, ¿qué porcentaje de aprobados hay? (**0.25 puntos**)
#
# c) ¿Qué entrega ha ido mejor? ¿Y cuál ha ido peor? Podéis usar la función [where](https://numpy.org/doc/stable/reference/generated/numpy.where.html) de numpy para encontrar el índice del elemento. (**0.5 puntos**)
#
#
# d) El coordinador nos ha informado que se han introducido modificaciones en los parámetros de evaluación que debemos aplicar. Ahora, no todas las entregas tienen el mismo peso en la calificación final, sino que se distribuyen de la siguiente manera: Entrega 1 (10%), Entrega 2 (15%), Entrega 3 (25%), Entrega 4 (15%), Entrega 5 (15%), y Entrega 6 (20%).
#
# Aplica estas ponderaciones y calcula la nueva nota promedio por estudiante. Para simplificar el proceso, es aconsejable utilizar la **multiplicación de matrices**.  ¿Por qué? Razona la respuesta.  (**0.5 puntos**)
#
# Para comprobar que funciona correctamente, calcula también la media de un hipotético alumno con todo 10.
#
# e) Como último detalle, se nos ha informado que los alumnos que hayan asistido a todas las clases y participado activamente pueden recibir un aumento del 10% en su nota final.
#
# Crea un array de 32 valores de 0 a 1, que indicarán si el alumno cumple con las condiciones. ¿Cuántos alumnos salen con valor 1?
#
# A continuación, incrementa en 10% la nota final de aquellos alumnos que hayan cumplido esta condición. Muestra por pantalla las notas finales con solo 1 decimal.(**0.5 puntos**)
#
# (**2 puntos**)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 6
#
# Después de completar todos los pasos, pon este código en forma de función siguiendo los puntos siguientes:
# - La función debe contar con tres parámetros de entrada: la matriz de notas para cada estudiante y entrega (con dimensiones n_alumnos x n_entregas), el array que contiene los porcentajes asignados a cada entrega, y el array binario compuesto por 0 y 1 que indica la buena asistencia y participación de los alumnos.
# - La función tiene que mostrar por pantalla:
# 1) El porcentaje de alumnos aprobados, 2) Las entregas con la mejor y la peor nota media y 3) el porcentaje de alumnos que han tenido buena asistencia y participación.
# - Como output la función tiene que devolver el array con las notas finales, con solo 1 decimal.
#
# Para verificar que la función es correcta, asegúrate de que el array de resultados sea idéntico al obtenido en los pasos anteriores del ejercicio. Para lograrlo, utiliza los mismos valores de entrada; si generas nuevos valores aleatorios, obtendrás arreglos diferentes.
#
# (**0.5 puntos**)

# %%
# Respuesta
